# %%
### This function downloads Google Drive Shared Files By Passing Its Sharing Link And The Desired Destination Path
###
## https://github.com/ndrplz/google-drive-downloader
## download datasets: pip install googledrivedownloader
def download_from_google_drive(id, destPath):
    """This function downloads Google Drive Shared Files By Passing Its Sharing Link And The Desired Destination Path     """
    ## confirm if the file already exists.
    import os.path
    if os.path.isfile(destPath):
        print("The File Already Exists. Please Change The Path Destination.");
        return False;
    # then download the file arguments = (file_id, dest_path, overwrite=False, unzip=False)
    from google_drive_downloader import GoogleDriveDownloader as gdd
    gdd.download_file_from_google_drive(file_id=id,
                                        dest_path=destPath);
    ## confirm if the file was saved
    if os.path.isfile(destPath):
        print("Success Downloading File.");
        return True;
    else:
        print("The File Couldnt Be Downloaded. Please Confirm If The Parameters Are Correct.");
        return False;

# %%
'''
{
    "statistical": {
        "skewness": {
            "description": "Computes the skewness of a data set.",
            "use": "yes",
			"imports": "from scipy.stats.stats import skew",
            "function": "skew",
            "source": "Python 2.7, Scipy Library",
            "reference": "Zwillinger, D. and Kokoska, S. (2000). CRC Standard Probability and Statistics Tables and Formulae. Champman and Hall: New York. 2000. "
        },
        "kurtosis": {
            "description": "Computes the kurtosis (Pearson) of a data set.",
            "use": "yes",
			"imports": "from scipy.stats.stats import kurtosis",
            "function": "kurtosis",
            "source": "Python 2.7, Scipy Library",
            "reference": "Zwillinger, D. and Kokoska, S. (2000). CRC Standard Probability and Statistics Tables and Formulae. Champman and Hall: New York. 2000."
        },
        "histogram": {
            "description": "The grouping of the data into bins, plotting the number of members in each bin against the bin number.",
            "use": "no",
            "imports": "from features import *",
            "function": "hist_json",
            "free parameters":{"nbins": [10, 20, 3],  "r": [1, 3, 2]},
            "number of features": 3,
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        }
    },
    "temporal": {
        "mean": {
            "description": "Computes the arithmetic mean along the specified axis.",
            "use": "yes",
			"imports": "from numpy import mean",
            "function": "mean",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        },
        "max": {
            "description": "Computes the maximum value along the specified axis.",
            "use": "yes",
			"imports": "from numpy import max",
            "function": "max",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        },
        "min": {
            "description": "Computes the minimum value along the specified axis.",
            "use": "yes",
			"imports": "from numpy import min",
            "function": "min",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        },
        "variance": {
            "description": "Computes the variance of a data set.",
            "use": "no",
			"imports": "from statistics import pvariance",
            "function": "pvariance",
            "source": "Python 2.7, Statistics Library",
            "reference": "Python 2.7, Statistics Library"
        },
        "centroid": {
            "description": "Computes the centroid of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "centroid",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
        "standard_deviation": {
            "description": "Computes the standard deviation along the specified axis.",
            "use": "yes",
			"imports": "from numpy import std",
            "function": "std",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        },
        "root_mean_square": {
            "description": "The square root of the arithmetic mean (average) of the squares of the original values.",
            "use": "yes",
			"imports": "from features import *",
            "function": "rms",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        },
        "interquartile_range": {
            "description": "Computes the interquartile range for the provided sequence of values, a more robust estimation than the variance.",
            "use": "no",
			"imports": "from astropysics.utils import interquartile_range",
            "function": "interquartile_range",
            "source": "Python 2.7, Astropysics Library",
            "reference": "Python 2.7, Astropysics Library"
        },
		"median_absolute_deviation": {
            "description": "Computes the median absolute deviation for the provided sequence of values, a more robust estimation than the variance.",
            "use": "no",
			"imports": "from astropysics.utils import median_absolute_deviation",
            "function": "calc_mad",
            "source": "Python 2.7, Astropysics Library",
            "reference": "Python 2.7, Astropysics Library"
        },
        "zero_crossing_rate": {
            "description": "The zero-crossing rate is a measure of the number of time the signal value cross the zero axe.",
            "use": "no",
			"imports": "from features import *",
            "function": "zero_cross",
            "source": "NovaInstrumentation",
            "reference": "NovaInstrumentation"
        },
        "cepstral_coefficients": {
            "description": "Compute cepstral coefficients along the specified axis.",
            "use": "no",
			"imports": "from features import *",
            "function": "ceps_coeff",
			"free parameters":{"coefNumber": [1, 11, 3]},
            "number of features": "coefNumber - 1",
            "source": "NovaInstrumentation",
            "reference": "NovaInstrumentation"
		},
		"correlation": {
            "description":"Compute the Pearson Correlation coefficient along the specified axes.",
            "use": "no",
			"imports": "from features import *",
            "function": "correlation",
            "number of features": 3,
            "source": "Python 2.7, Scipy Library",
            "reference": "www.statsoft.com/textbook/glosp.html#Pearson%20Correlation"
		},
		"autocorrelation": {
            "description": "Cross correlation of 1dimensional sequence.",
            "use": "no",
			"imports": "from features import *",
            "function": "autocorr",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        }
    },
    "spectral": {
        "max_frequency": {
            "description": "Compute the one-dimensional discrete Fourier Transform and with cumsum function find 95% of max frequency.",
            "use": "no",
			"imports": "from features import *",
            "function": "max_frequency",
			"parameters": "FS",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        },
        "median_frequency": {
            "description": "Compute the one-dimensional discrete Fourier Transform and with cumsum function find 50% of max frequency.",
            "use": "no",
			"imports": "from features import *",
            "function": "median_frequency",
			"parameters": "FS",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        },
		"fundamental_frequency": {
            "description": "Computes the fundamental frequency along the specified axis.For an harmonic signal,the fundamental frequency is the frequency so thats its integer multiple best explain the content of the signal spectrum.",
			"use": "no",
            "imports": "from features import *",
            "function": "fundamental_frequency",
			"parameters":"FS",
            "source": "NovaInstrumentation Library",
            "reference": "NovaInstrumentation Library"
        },
		"max_power_spectrum": {
            "description": "Compute power spectrum density along the specified axes and return the maximum value.",
            "use": "no",
			"imports": "from features import *",
            "function": "power_spectrum",
            "parameters":"FS",
            "source": "Python 2.7, Numpy Library",
            "reference": "Python 2.7, Numpy Library"
        },
        "total_energy": {
            "description": "Computes the total energy of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "total_energy_",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
			"reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
        "spectral_centroid": {
            "description": "Computes the spectral centroid of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "spectral_centroid",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
        "spectral_spread": {
            "description": "Computes the spectral spread of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "spectral_spread",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
        "spectral_skewness": {
            "description": "Computes the spectral skewness of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "spectral_skewness",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
		"spectral_kurtosis": {
            "description": "Computes the spectral kurtosis of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "spectral_kurtosis",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
		"spectral_slope": {
            "description": "Computes the spectral slope of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "spectral_slope",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
		"spectral_decrease": {
            "description": "Computes the spectral decrease of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "spectral_decrease",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
        "spectral_roll_on": {
            "description": "Computes the spectral roll-on of a dataset.",
            "use": "no",
			"imports": "from features import *",
            "function": "spectral_roll_on",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
        "spectral_roll_off": {
            "description": "Computes the spectral roll-off of a dataset.",
            "use": "no",
			"imports": "from features import *",
            "function": "spectral_roll_off",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
        "curve_distance": {
            "description": "Computes the curve distance of a dataset.",
            "use": "no",
			"imports": "from features import *",
            "function": "curve_distance",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "Carina Figueira, 2015."
        },
		"spect_variation": {
            "description": "Computes the spectral variation of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "spect_variation",
            "parameters": "FS",
            "source": "Python 2.7, Scipy Library",
            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."
        },
        "wavelets_energy": {
            "description": "Computes the wavelets energy of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "wavelets_energy",
            "source": "Python 2.7, Scipy Library."
        },
        "linear_regression": {
            "description": "Computes the linear regression of a data set.",
            "use": "no",
			"imports": "from features import *",
            "function": "linear_regression",
            "source": "Python 2.7, Numpy Library"
        }
    }
}
'''
# Out:
# '\n{\n    "statistical": {\n        "skewness": {\n            "description": "Computes the skewness of a data set.",\n            "use": "yes",\n\t\t\t"imports": "from scipy.stats.stats import skew",\n            "function": "skew",\n            "source": "Python 2.7, Scipy Library",\n            "reference": "Zwillinger, D. and Kokoska, S. (2000). CRC Standard Probability and Statistics Tables and Formulae. Champman and Hall: New York. 2000. "\n        },\n        "kurtosis": {\n            "description": "Computes the kurtosis (Pearson) of a data set.",\n            "use": "yes",\n\t\t\t"imports": "from scipy.stats.stats import kurtosis",\n            "function": "kurtosis",\n            "source": "Python 2.7, Scipy Library",\n            "reference": "Zwillinger, D. and Kokoska, S. (2000). CRC Standard Probability and Statistics Tables and Formulae. Champman and Hall: New York. 2000."\n        },\n        "histogram": {\n            "description": "The grouping of the data into bins, plotting the number of members in each bin against the bin number.",\n            "use": "no",\n            "imports": "from features import *",\n            "function": "hist_json",\n            "free parameters":{"nbins": [10, 20, 3],  "r": [1, 3, 2]},\n            "number of features": 3,\n            "source": "Python 2.7, Numpy Library",\n            "reference": "Python 2.7, Numpy Library"\n        }\n    },\n    "temporal": {\n        "mean": {\n            "description": "Computes the arithmetic mean along the specified axis.",\n            "use": "yes",\n\t\t\t"imports": "from numpy import mean",\n            "function": "mean",\n            "source": "Python 2.7, Numpy Library",\n            "reference": "Python 2.7, Numpy Library"\n        },\n        "max": {\n            "description": "Computes the maximum value along the specified axis.",\n            "use": "yes",\n\t\t\t"imports": "from numpy import max",\n            "function": "max",\n            "source": "Python 2.7, Numpy Library",\n            "reference": "Python 2.7, Numpy Library"\n        },\n        "min": {\n            "description": "Computes the minimum value along the specified axis.",\n            "use": "yes",\n\t\t\t"imports": "from numpy import min",\n            "function": "min",\n            "source": "Python 2.7, Numpy Library",\n            "reference": "Python 2.7, Numpy Library"\n        },\n        "variance": {\n            "description": "Computes the variance of a data set.",\n            "use": "no",\n\t\t\t"imports": "from statistics import pvariance",\n            "function": "pvariance",\n            "source": "Python 2.7, Statistics Library",\n            "reference": "Python 2.7, Statistics Library"\n        },\n        "centroid": {\n            "description": "Computes the centroid of a data set.",\n            "use": "no",\n\t\t\t"imports": "from features import *",\n            "function": "centroid",\n            "parameters": "FS",\n            "source": "Python 2.7, Scipy Library",\n            "reference": "G. Peeters, “A large set of audio features for sound description (similarity and classification) in the cuidado project”, 2004."\n        },\n        "standard_deviation": {\n            "description": "Computes the standard deviation along the specified axis.",\n            "use": "yes",\n\t\t\t"imports": "from numpy import std",\n            "function": "std",\n            "source": "Python 2.7, Numpy Library",\n            "reference": "Python 2.7, Numpy Library"\n        },\n        "root_mean_square": {\n            "description": "The square root of the arithmetic mean (average) of the squares of the original values.",\n            "use": "yes",\n\t\t\t"imports": "from features import *",\n            "function": "rms",\n            "source": "Python 2.7, Numpy Library",\n            "reference": "Python 2.7, Numpy Library"\n        },\n        "interquartile_range": {\n            "description": "Computes the interquartil ...

# %%
### Statistical Feature Extraction
# skeweness
>>> from scipy.stats import skew
>>> skew([1, 2, 3, 4, 5])
# kurtois
from scipy.stats import kurtosis
kurtosis([1, 2, 3, 4, 5])
# histogram
np.histogram([1, 2, 1], bins=[0, 1, 2, 3])
(array([0, 2, 1]), array([0, 1, 2, 3]))
np.histogram(np.arange(4), bins=np.arange(5), density=True)
(array([ 0.25,  0.25,  0.25,  0.25]), array([0, 1, 2, 3, 4]))
np.histogram([[1, 2, 1], [1, 0, 1]], bins=[0,1,2,3])
(array([1, 4, 1]), array([0, 1, 2, 3]))



### Time Series Feature Extraction
#mean https://docs.scipy.org/doc/numpy/reference/generated/numpy.mean.html
a = np.array([1, 2])
np.mean(a)
#max
np.array([1, 2]).max()
#min
np.array([1, 2]).min()
#variance https://docs.scipy.org/doc/numpy-1.6.0/reference/generated/numpy.var.html
a = np.array([[1,2],[3,4]])
np.var(a)
np.var(a,0)
#centroid
from scipy import ndimage
print(float(ndimage.measurements.center_of_mass(data)[0]))
#standard deviation https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.std.html
a = np.array([[1, 2], [3, 4]])
np.std(a)
#root mean square
print(np.sqrt(np.mean(data**2)))
#interquartile range
from scipy.stats import iqr
print(iqr(data))
#mean absolute deviation
import numpy as np
from astropy.stats import median_absolute_deviation
from numpy.random import randn
mad = median_absolute_deviation(data)
print(mad)
#zero crossing rate
import numpy as np
my_array = np.array([80.6, 120.8, -115.6, -76.1, 131.3, 105.1, 138.4, -81.3, -95.3,  
                     89.2, -154.1, 121.4, -85.1, 96.8, 68.2])
((my_array[:-1] * my_array[1:]) < 0).sum()
#cepstral coefficients https://librosa.github.io/librosa/generated/librosa.feature.mfcc.html
y, sr = librosa.load(librosa.util.example_audio_file())
librosa.feature.mfcc(y=y, sr=sr)
#correlation
import pandas as pd
data = pd.Series([1,2,3,4,5,9]);
print(data.corr(data, method='pearson'))
print(data.corr(data, method='kendall'))
print(data.corr(data, method='spearman'))
#autocorrelation
import pandas as pd
data = pd.Series([1,2,3,4,5,9]);
print(data.autocorr())



### Spectral Features
#max frequency description: "Compute the one-dimensional discrete Fourier Transform and with cumsum function find 95% of max frequency.",
array = np.fft.fft(np.exp(2j * np.pi * np.arange(8) / 8))
array_sort = array.sort(reverse=True)
array_sort = np.cumsum(array_sort)
array95 = array_sort[0 : int(len(array_sort) * .95)]
#median frequency description: "Compute the one-dimensional discrete Fourier Transform and with cumsum function find 50% of max frequency.",
array = np.fft.fft(np.exp(2j * np.pi * np.arange(8) / 8))
array_sort = array.sort(reverse=True)
array_sort = np.cumsum(array_sort)
array50 = array_sort[0 : int(len(array_sort) * .50)]
#fundamental frequency description: "Computes the fundamental frequency along the specified axis.For an harmonic signal,the fundamental frequency is the frequency so thats its integer multiple best explain the content of the signal spectrum.",

#max power spectrum description: "Compute power spectrum density along the specified axes and return the maximum value.",
'''https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.signal.periodogram.html'''
f, Pxx_den = signal.periodogram(array, fs)

#total energy             "description": "Computes the total energy of a data set.",
'''
https://www.mathworks.com/matlabcentral/answers/159105-i-have-a-time-domain-signal-i-want-to-calculate-energy-of-my-signal
'''
F = fft(values);
pow = F.*conj(F);
total_pow = sum(pow);

#spectral centroid             "description": "Computes the spectral centroid of a data set.",
'''
https://www.google.pt/search?q=spectral+centroid+python&oq=spectral+centroid+&aqs=chrome.3.69i57j0l5.1848j0j4&sourceid=chrome&ie=UTF-8
'''
import numpy as np

def spectral_centroid(x, samplerate=44100):
    magnitudes = np.abs(np.fft.rfft(x)) # magnitudes of positive frequencies
    length = len(x)
    freqs = np.abs(np.fft.fftfreq(length, 1.0/samplerate)[:length//2+1]) # positive frequencies
    return np.sum(magnitudes*freqs) / np.sum(magnitudes) # return weighted mean

#spectral_spread "            ""description"": ""Computes the spectral spread of a data set."",

#spectral skweness "            ""description"": ""Computes the spectral skewness of a data set."",

#spectral kurtosis "            ""description"": ""Computes the spectral kurtosis of a data set."",

#spectral slope "            ""description"": ""Computes the spectral slope of a data set."",

#spectral decrease "            ""description"": ""Computes the spectral decrease of a data set."",

#spectral roll on "            ""description"": ""Computes the spectral roll-on of a dataset."",

#spectral roll off "            ""description"": ""Computes the spectral roll-off of a dataset."",

#curve distance "            ""description"": ""Computes the curve distance of a dataset."",

#spect variation "            ""description"": ""Computes the spectral variation of a data set."",

#wavelets energy "            ""description"": ""Computes the wavelets energy of a data set."",

#linear regression             "description": "Computes the linear regression of a data set.",
# Out:
# 0.936329177569
# 1.0
# 1.0
# 1.0
# 1.5
# 2.5
# 4.7609522857
# 3.5416666666666665
